# %% [markdown]
# # GPT-2 From Scratch
#
# ## Chapter 1: Understanding the Dataset
#
# Goal:
# - Load the Tiny Shakespeare dataset
# - Explore its contents
# - Understand what the model sees before any preprocessing

# %%
from pathlib import Path
DATA_PATH = Path("../data/input.txt")
with open(DATA_PATH, "r", encoding="utf-8") as f:
    text = f.read()

# %%
len(text)
# Out:
# 1115394

# %%
print(type(text))
# Out:
# <class 'str'>
